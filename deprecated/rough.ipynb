# %%
# %pip install --upgrade --force-reinstall pandas -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\guran\AppData\Local\Programs\Python\Python312\Lib\site-packages\~~mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\guran\AppData\Local\Programs\Python\Python312\Lib\site-packages\~~mpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\guran\AppData\Local\Programs\Python\Python312\Lib\site-packages\~andas.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\guran\AppData\Local\Programs\Python\Python312\Lib\site-packages\~andas'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import pandas as pd

df = pd.read_json("candidates_small.jsonl", lines=True)
df
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import pandas as pd
#       3 df = pd.read_json("candidates_small.jsonl", lines=True)
#       4 df
#
# File c:\Users\guran\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\__init__.py:121
#      56 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#      58 from pandas.core.api import (
#      59     # dtype
#      60     ArrowDtype,
#    (...)
#     119     DataFrame,
#     120 )
# --> 121 from pandas.core.col import col
#     123 from pandas.core.dtypes.dtypes import SparseDtype
#     125 from pandas.tseries.api import infer_freq
#
# File c:\Users\guran\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\col.py:14
#       3 from collections.abc import (
#       4     Callable,
#       5     Hashable,
#       6     Sequence,
# ...

# %%
pip uninstall pandas -y
# Out:
# Found existing installation: pandas 3.0.3
# Uninstalling pandas-3.0.3:
#   Successfully uninstalled pandas-3.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --no-cache-dir pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 5.6 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/9.8 MB 4.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/9.8 MB 4.6 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.8 MB 5.1 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.8 MB 4.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.8 MB 4.8 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.8 MB 4.6 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.8 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.8 MB 4.6 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.8 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 4.5 MB/s  0:00:02
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
