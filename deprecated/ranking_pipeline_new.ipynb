# %% [markdown]
# # Redrob Hackathon — Candidate Ranking Pipeline
#
# Recruiter-style ranking of **Top 100** candidates for the *Founding Senior AI Engineer* role.
#
# **Guiding philosophy:** *Eliminate only candidates who are extremely unlikely to be selected per the JD. Everything else is expressed as preferences through scoring.*
#
# ## Pipeline
# ```
# 100,000 Candidates
#       │
#       ▼  Stage 1: Direct Eliminations  (hard rejects)
# Filtered Pool
#       │
#       ▼  Stage 2: Candidate Scoring     (weighted sub-scores)
# Scored Candidates
#       │
#       ▼  Stage 3: Honeypot Detection    (reject / penalize)
# Final Top 100
#       │
#       ▼  Reasoning Generation
# submission.csv
# ```
#
# ## Compute constraints (from `submission_spec.md`)
# - **≤ 5 min** wall-clock, **CPU only**, **≤ 16 GB RAM**, **no network during ranking**, **≤ 5 GB disk**.
# - Pre-computation (model download, pip installs) is allowed **outside** the 5-min window.
# - Output CSV columns: `candidate_id, rank, score, reasoning` (100 rows, `score` monotonically non-increasing).
# - **Honeypot rate > 10% in top 100 = disqualification.**
#
# > **Run order:** execute cells top-to-bottom. The first cell installs dependencies (run once, requires network). After that, the ranking itself uses no network."

# %% [markdown]
# ## 0. Setup &amp; Configuration
#
# The cell below installs dependencies (run once, needs network). `sentence-transformers` is optional — if it (or the model) is unavailable, the pipeline automatically falls back to **BM25 + TF-IDF** for semantic matching.

# %%
# Run ONCE (needs network). Safe to re-run; it is a no-op if already installed.
# %pip install -q pandas numpy scikit-learn rank-bm25 sentence-transformers
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
import time
import warnings
from datetime import datetime

import numpy as np
import pandas as pd

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 50)

# ----------------------------- RUN CONFIG ---------------------------------
DATA_PATH = "India_runs_data_and_ai_challenge/candidates.jsonl"
OUTPUT_CSV = "submission.csv"
TOP_N = 100

# Semantic matching backend. If sentence-transformers / model unavailable,
# the pipeline degrades gracefully to BM25 + TF-IDF.
USE_DENSE_EMBEDDINGS = True
EMBED_MODEL = "all-MiniLM-L6-v2"   # small, CPU-friendly, ~80MB

# Reference "today" for recency calculations. The dataset is synthetic and
# dated in the future, so we anchor recency to the most recent last_active_date
# observed in the data (computed at load time). Override here if desired.
REFERENCE_DATE = None  # None -> auto (max last_active_date)

# ------------------------- AGGREGATION WEIGHTS ----------------------------
# Final score = weighted average of sub-scores, then multiplied by the
# CV/Robotics/Speech penalty multiplier (<=1.0). Weights sum to 1.0.
WEIGHTS = {
    "jd_alignment": 0.30,   # semantic + keyword fit to the JD
    "experience":   0.20,   # applied-AI years + total years (peaked)
    "behavioral":   0.15,   # redrob signals (availability / engagement)
    "production":   0.15,   # evidence of shipping production ML
    "location":     0.10,   # geography vs preferred hubs
    "like_to_have": 0.10,   # nice-to-have bonuses
}
assert abs(sum(WEIGHTS.values()) - 1.0) < 1e-9, "Weights must sum to 1.0"

print("Config loaded. Weights:", WEIGHTS)
# Out:
# Config loaded. Weights: {'jd_alignment': 0.3, 'experience': 0.2, 'behavioral': 0.15, 'production': 0.15, 'location': 0.1, 'like_to_have': 0.1}

# %%
# ============================ LEXICONS ====================================
# All matching is lowercase substring / token based (fast, no heavy regex).

# Preferred metro hubs (Stage 1 location filter + Stage 2 location score)
PREFERRED_PRIMARY = ["pune", "noida"]
PREFERRED_SECONDARY = ["delhi", "ncr", "gurgaon", "gurugram", "mumbai", "hyderabad"]
PREFERRED_LOCATIONS = PREFERRED_PRIMARY + PREFERRED_SECONDARY

# ----- AI/ML relevant SKILLS (exhaustive mapping over the 133 dataset skills
#       + JD terminology + synonyms). Matched against the skills[].name field.
RELEVANT_SKILLS = [
    "nlp", "natural language", "machine learning", "deep learning", "pytorch",
    "tensorflow", "keras", "jax", "scikit-learn", "sklearn", "xgboost", "lightgbm",
    "embeddings", "sentence transformers", "bert", "transformers", "hugging face",
    "huggingface", "llm", "llms", "large language", "fine-tuning", "fine tuning",
    "fine-tuning llms", "lora", "qlora", "peft", "rag", "langchain", "llamaindex",
    "prompt engineering", "information retrieval", "retrieval", "semantic search",
    "vector search", "learning to rank", "ranking", "recommendation systems",
    "recommendation system", "recommender", "bm25", "faiss", "pinecone", "weaviate",
    "qdrant", "milvus", "pgvector", "chroma", "elasticsearch", "opensearch",
    "neural networks", "neural network", "feature engineering", "mlops", "mlflow",
    "kubeflow", "bentoml", "weights & biases", "wandb", "statistical modeling",
    "data science", "diffusion models", "reinforcement learning", "cnn", "rnn",
    "lstm", "gan", "computer vision", "image classification", "object detection",
    "speech recognition", "asr", "tts", "yolo", "opencv", "haystack",
]

# ----- Relevant TITLE keywords (current OR past title)
RELEVANT_TITLE_KEYWORDS = [
    "ml engineer", "machine learning", "data scientist", "applied scientist",
    "applied ml", "ai engineer", "nlp engineer", "search engineer",
    "relevance engineer", "recommendation", "recommender", "research engineer",
    "deep learning", "ai/ml", "ai specialist", "ml scientist", "ranking engineer",
    "computer vision", "research scientist", "ml researcher",
]

# Titles that count as "tech" for the non-tech elimination whitelist
TECH_WHITELIST_TITLES = [
    "engineer", "developer", "scientist", "architect", "data analyst",
    "analytics engineer", "data engineer", "bi engineer", "research",
    "programmer", "sde", "swe", "devops", "sre", "platform", "ml", "ai",
    "cto", "vp engineering", "tech lead", "technical lead",
]

# Non-tech title categories (entire-career-non-tech elimination)
NON_TECH_TITLE_KEYWORDS = [
    "marketing", "sales", "accountant", "account executive", "hr ", "human resources",
    "recruiter", "talent acquisition", "operations manager", "content writer",
    "customer support", "customer success", "teacher", "finance", "legal",
    "business development", "brand", "seo specialist", "logistics",
    "mechanical engineer", "civil engineer", "electrical engineer",  # non-software eng
]

# ----- Career-description EVIDENCE of relevant work (Stage 1 + JD alignment)
CAREER_EVIDENCE_KEYWORDS = [
    "retrieval", "ranking", "re-rank", "rerank", "recommendation", "recommender",
    "relevance", "search", "embedding", "embeddings", "semantic", "vector",
    "evaluation", "ndcg", "mrr", "recall@", "precision@", "deployed", "production",
    "machine learning", "deep learning", "nlp", "language model", "llm",
    "fine-tune", "fine-tuning", "classifier", "model", "inference", "pipeline",
]

# ----- Consulting / services companies (consulting-only elimination)
# Broadened net: major Indian IT services, global consulting/BPO.
# Only real company names — fictional companies will NOT match and are NOT penalized.
CONSULTING_COMPANIES = [
    # Indian IT Services (Big-5 + others)
    "tcs", "tata consultancy", "infosys", "wipro", "accenture", "cognizant",
    "capgemini", "hcl", "tech mahindra", "mindtree", "mphasis", "ltimindtree",
    "lti", "l&t infotech", "l&t technology", "larsen", "deloitte", "ey ", "kpmg",
    "pwc", "ibm global", "ibm consulting",
    # Mid-tier Indian IT services
    "dxc", "hexaware", "birlasoft", "coforge", "persistent systems", "zensar",
    "cyient", "niit technologies", "sasken", "sonata software", "virtusa",
    "ust global", "ust ", "syntel", "polaris", "igate", "globallogic",
    "genpact", "exl", "wns", "hinduja", "mu sigma", "mascon",
    # Global consulting / outsourcing
    "epam", "ntt data", "cgi ", "atos", "sopra steria", "conduent", "unisys",
    "thoughtworks", "nagarro", "xoriant", "kellton", "happiest minds",
    "l&t technology services", "harman", "tavant", "impetus", "sapient",
    "publicis sapient", "ness digital", "mindcubed", "microland",
]

# ----- Retrieval / Eval / LLM signal lexicons (JD alignment sub-signals)
RETRIEVAL_SIGNALS = [
    "retrieval", "search", "relevance", "ranking", "recommendation", "matching",
    "embedding", "semantic", "vector", "bm25", "learning to rank",
]
EVAL_SIGNALS = [
    "ndcg", "mrr", "map ", "mean average precision", "evaluation", "offline",
    "online", "benchmark", "a/b test", "ab test", "precision@", "recall@",
]
LLM_SIGNALS = [
    "prompt engineering", "fine-tun", "fine tun", "llm", "large language",
    "rag", "deployment", "gpt", "instruction tun", "peft", "lora",
]

# ----- Production evidence lexicon
PRODUCTION_KEYWORDS = [
    "production", "deployed", "deploy", "scaled", "scale", "monitoring",
    "latency", "throughput", "pipeline", "pipelines", "users", "serving",
    "real-time", "real time", "millions", "high-traffic", "uptime", "sla",
]

# ----- Pure-research detection
RESEARCH_KEYWORDS = [
    "research scientist", "phd researcher", "postdoc", "publication", "published",
    "paper", "academia", "university research", "thesis", "research fellow",
]

# ----- Like-to-have bonus groups
LIKE_TO_HAVE = {
    "fine_tuning": ["lora", "qlora", "peft", "fine-tun", "fine tun"],
    "learning_to_rank": ["lambdamart", "xgboost ranker", "learning to rank",
                          "neural rank", "ltr"],
    "hr_tech": ["recruitment", "talent matching", "hiring", "recruiter", "ats",
                "candidate matching", "hr-tech", "hr tech"],
    "distributed": ["inference optimization", "distributed serving", "distributed",
                    "quantization", "onnx", "triton", "tensorrt"],
    "open_source": ["open source", "open-source", "github", "contributor",
                    "maintainer", "oss"],
}

# ----- Domain penalty lexicons (CV / Speech / Robotics without IR evidence)
CV_KEYWORDS = ["yolo", "opencv", "segmentation", "object detection", "image classification", "cnn", "computer vision"]
SPEECH_KEYWORDS = ["asr", "wav2vec", "audio", "tts", "speech recognition", "voice"]
ROBOTICS_KEYWORDS = ["ros", "slam", "motion planning", "robotics", "lidar"]
IR_CORE_KEYWORDS = ["retrieval", "ranking", "recommendation", "search", "relevance", "evaluation", "embedding"]

# Number of candidates to pass through to dense-embedding stage (late-stage optimization)
DENSE_SHORTLIST_N = 500

print("Lexicons loaded.")
# Out:
# Lexicons loaded.

# %% [markdown]
# ## 1. Data Loading &amp; Feature Engineering
#
# Load `candidates.jsonl`, flatten the nested structures, and build a single
# per-candidate feature table that downstream stages consume. All text is
# lowercased and aggregated once here so the elimination/scoring stages are fast.

# %%
t0 = time.time()
raw = pd.read_json(DATA_PATH, lines=True)
print(f"Loaded {len(raw):,} candidates in {time.time()-t0:.1f}s")

# ---- small helpers -------------------------------------------------------
def _lower(x):
    return str(x).lower() if x is not None else ""

def any_kw(text, keywords):
    """True if any keyword is a substring of text (text already lowercased)."""
    return any(k in text for k in keywords)

def count_kw(text, keywords):
    """Number of distinct keywords found in text."""
    return sum(1 for k in keywords if k in text)

def parse_date(s):
    if not s or (isinstance(s, float) and np.isnan(s)):
        return pd.NaT
    return pd.to_datetime(s, errors="coerce")
# Out:
# Loaded 100,000 candidates in 12.8s

# %%
# ---------------- Build the per-candidate feature table -------------------
records = raw.to_dict("records")
rows = []

for rec in records:
    cid = rec.get("candidate_id")
    prof = rec.get("profile") or {}
    sig = rec.get("redrob_signals") or {}
    careers = rec.get("career_history") or []
    skills = rec.get("skills") or []

    # --- profile ---
    headline = _lower(prof.get("headline"))
    summary = _lower(prof.get("summary"))
    location = _lower(prof.get("location"))
    country = _lower(prof.get("country"))
    cur_title = _lower(prof.get("current_title"))
    yoe = prof.get("years_of_experience")
    yoe = float(yoe) if yoe is not None else np.nan

    # --- skills ---
    skill_names = [_lower(s.get("name")) for s in skills]
    skills_text = " ".join(skill_names)
    # relevant skill present (+ require positive duration when duration exists)
    has_relevant_skill = False
    for s in skills:
        nm = _lower(s.get("name"))
        if any(k in nm for k in RELEVANT_SKILLS):
            dur = s.get("duration_months")
            if dur is None or dur > 0:
                has_relevant_skill = True
                break
    # expert skills with ~0 duration (honeypot signal)
    expert_zero_dur = sum(
        1 for s in skills
        if _lower(s.get("proficiency")) == "expert" and (s.get("duration_months") or 0) <= 1
    )
    n_expert = sum(1 for s in skills if _lower(s.get("proficiency")) == "expert")

    # --- careers ---
    titles_past = [_lower(c.get("title")) for c in careers]
    titles_all = " | ".join([cur_title] + titles_past)
    descs = [_lower(c.get("description")) for c in careers]
    career_text = " ".join(descs)
    companies = [_lower(c.get("company")) for c in careers]
    durations = [float(c.get("duration_months") or 0) for c in careers]
    total_months = sum(durations)
    total_companies = len(set(companies))

    # job-hopping: fraction of jobs with tenure < 18 months
    short_jobs = sum(1 for d in durations if 0 < d < 18)
    short_switch_ratio = (short_jobs / len(durations)) if durations else 0.0

    # consulting exposure
    consulting_months = sum(
        d for c, d in zip(companies, durations) if any(k in c for k in CONSULTING_COMPANIES)
    )
    consulting_ratio = (consulting_months / total_months) if total_months > 0 else 0.0
    all_consulting = (
        len(companies) > 0 and all(any(k in c for k in CONSULTING_COMPANIES) for c in companies)
    )

    # title relevance
    title_relevant = any_kw(titles_all, RELEVANT_TITLE_KEYWORDS)
    # career-description evidence
    career_evidence = any_kw(career_text, CAREER_EVIDENCE_KEYWORDS)

    # entire-career-non-tech: every job non-tech, none tech-whitelisted, no AI evidence
    def _is_tech_title(t):
        return any(k in t for k in TECH_WHITELIST_TITLES)
    def _is_nontech_title(t):
        return any(k in t for k in NON_TECH_TITLE_KEYWORDS)
    all_titles = [t for t in ([cur_title] + titles_past) if t]
    non_tech_all = (
        len(all_titles) > 0
        and all((_is_nontech_title(t) and not _is_tech_title(t)) for t in all_titles)
        and not has_relevant_skill
        and not career_evidence
    )

    # research vs production (research months = tenure of clearly-research roles)
    research_months = 0.0
    for c, d in zip(careers, durations):
        ttl = _lower(c.get("title")) + " " + _lower(c.get("description"))
        if any(k in ttl for k in RESEARCH_KEYWORDS):
            research_months += d
    research_ratio = (research_months / total_months) if total_months > 0 else 0.0
    production_evidence = any_kw(career_text + " " + summary, PRODUCTION_KEYWORDS)

    # applied AI/ML years: sum tenure of roles showing AI/ML evidence
    applied_ai_months = 0.0
    for c, d in zip(careers, durations):
        blob = _lower(c.get("title")) + " " + _lower(c.get("description"))
        if any_kw(blob, RELEVANT_TITLE_KEYWORDS) or any_kw(blob, CAREER_EVIDENCE_KEYWORDS):
            applied_ai_months += d
    applied_ai_years = applied_ai_months / 12.0

    # full text used for semantic retrieval (titles + descriptions + skills + profile)
    full_text = " ".join([titles_all, career_text, skills_text, headline, summary]).strip()

    # --- signals ---
    rows.append({
        "candidate_id": cid,
        "headline": headline, "summary": summary,
        "location": location, "country": country,
        "current_title": cur_title, "years_of_experience": yoe,
        "current_company": _lower(prof.get("current_company")),
        "current_industry": _lower(prof.get("current_industry")),
        # skills / titles / text
        "skill_names": skill_names, "skills_text": skills_text,
        "titles_all": titles_all, "career_text": career_text,
        "full_text": full_text,
        # derived booleans / ratios
        "has_relevant_skill": has_relevant_skill,
        "title_relevant": title_relevant,
        "career_evidence": career_evidence,
        "n_expert": n_expert, "expert_zero_dur": expert_zero_dur,
        "total_months": total_months, "total_companies": total_companies,
        "short_switch_ratio": short_switch_ratio,
        "consulting_ratio": consulting_ratio, "all_consulting": all_consulting,
        "non_tech_all": non_tech_all,
        "research_ratio": research_ratio, "production_evidence": production_evidence,
        "applied_ai_years": applied_ai_years,
        # signals
        "open_to_work": bool(sig.get("open_to_work_flag")),
        "willing_to_relocate": bool(sig.get("willing_to_relocate")),
        "last_active_date": parse_date(sig.get("last_active_date")),
        "recruiter_response_rate": sig.get("recruiter_response_rate"),
        "interview_completion_rate": sig.get("interview_completion_rate"),
        "notice_period_days": sig.get("notice_period_days"),
        "github_activity_score": sig.get("github_activity_score"),
        "profile_completeness_score": sig.get("profile_completeness_score"),
    })

feat = pd.DataFrame(rows).set_index("candidate_id")
print(f"Feature table built: {feat.shape[0]:,} rows x {feat.shape[1]} cols in {time.time()-t0:.1f}s")

# Resolve reference date for recency
ref_date = pd.to_datetime(REFERENCE_DATE) if REFERENCE_DATE else feat["last_active_date"].max()
feat["days_since_active"] = (ref_date - feat["last_active_date"]).dt.days
print("Reference date for recency:", ref_date)
feat.head(3)
# Out:
# Feature table built: 100,000 rows x 35 cols in 97.1s
# Reference date for recency: 2026-05-27 00:00:00
#                                                headline  \
# candidate_id
# CAND_0000001       backend engineer | sql, spark, cloud
# CAND_0000002  operations manager | 12.5+ yrs experience
# CAND_0000003     customer support | 1.1+ yrs experience
#
#                                                         summary  \
# candidate_id
# CAND_0000001  software / data professional with 6.9 years of...
# CAND_0000002  professional with 12.5+ years of experience. m...
# CAND_0000003  professional with 1.1+ years of experience. i'...
#
#                          location country       current_title  \
# candidate_id
# CAND_0000001              toronto  canada    backend engineer
# CAND_0000002  chennai, tamil nadu   india  operations manager
# CAND_0000003               austin     usa    customer support
#
#               years_of_experience current_company current_industry  \
# candidate_id
# CAND_0000001                  6.9        mindtree      it services
# CAND_0000002                 12.5           wipro      it services
# CAND_0000003                  1.1             tcs      it services
#
#                                                     skill_names  \
# candidate_id
# CAND_0000001  [tailwind, nlp, image classification, fine-tun...
# CAND_0000002  [project management, react, photoshop, typescr...
# CAND_0000003  [angular, seo, excel, accounting, kubernetes, ...
#
#                                                     skills_text  \
# candidate_id
# CAND_0000001  tailwind nlp image classification fine-tuning ...
# CAND_0000002  project management react photoshop typescript ...
# CAND_0000003  angular seo excel accounting kubernetes databr...
#
#                                                      titles_all  \
# candidate_id
# CAND_0000001  backend engineer | backend engineer | analytic...
# CAND_0000002  operations manager | operations manager | oper...
# CAND_0000003                customer support | customer support
#
#                                                     career_text  \
# candidate_id
# CAND_0000001  implemented streaming data pipelines on kafka ...
# CAND_0000002  customer support team lead at a saas product. ...
# CAND_0000003  business analyst at a consulting firm, working...
#
#                                                       full_text  \
# candidate_id
# CAND_0000001  backend engineer | backend engineer | analytic...
# CAND_0000002  operations manager | operations manager | oper...
# CAND_0000003  customer support | customer support business a...
#
#               has_relevant_skill  title_relevant  career_evidence  n_expert  \
# candidate_id
# CAND_0000001                True           False             True         0
# CAND_0000002                True           False             True         0
# CAND_0000003               False           False             True         0
#
#               expert_zero_dur  total_months  total_companies  \
# candidate_id
# CAND_0000001                0          82.0                2
# CAND_0000002                0         149.0                3
# CAND_0000003                0          13.0                1
#
#               short_switch_ratio  consulting_ratio  all_consulting  \
# candidate_id
# CAND_0000001                0.00          0.329268           False
# CAND_0000002                0.25          0.382550           False
# CAND_0000003                1.00          1.000000            True
#
#               non_tech_all  research_ratio  production_evidence  \
# candidate_id
# CAND_0000001         False        0.000000                 True
# CAND_0000002         False        0.362416                 True
# CAND_0000003         False        0.000000                False
#
#               applied_ai_years  open_to_work  willing_to_relocate  \
# candidate_id
# CAND_0000001          6.833333          True                False
# CAND_0000002          8.833333          True                False
# CAND_0000003          1.083333         False                False
#
#              last_active_date  recruiter_response_rate  \
# candidate_id
# CAND_0000001       2026-05-20                     0.34
# CAND_0000002       2025-11-12                     0.29
# CAND_0000003       2026-03-21                     0.46
#
#               interview_completion_rate  notice_period_days  \
# candidate_id
# CAND_0000001                       0.71                  60
# CAND_0000002                       0.62                  60
# CAND_0000003                       0.86                 150
#
#               github_activity_score  profile_completeness_score  \
# candidate_id
# CAND_0000001                    9.2                        86.9
# CAND_0000002                   -1.0                        78.7
# CAND_0000003                   -1.0                        31.9
#
#               days_since_active
# candidate_id
# CAND_0000001                  7
# CAND_0000002                196
# CAND_0000003                 67

# %% [markdown]
# ## Stage 1 — Direct Eliminations
#
# A candidate is **eliminated** if they satisfy **ANY** hard reject rule below.
# These are deliberately conservative: we only cut candidates extremely unlikely
# to be selected per the JD. Everything else flows to scoring.
#
# 1. **Location** — not in preferred hubs AND not willing to relocate
# 2. **AI/ML evidence** — no relevant skill AND no relevant title AND no career evidence
# 3. **Extreme job-hopping** — (≥3 companies) and `short_switch_ratio > 0.7`
# 4. **Consulting-only** — every company is a consulting/services firm
# 5. **Entire-career non-tech** — every role non-tech, no AI evidence
# 6. **Pure research** *(optional)* — `research_ratio == 1` AND no production evidence

# %%
# --------------------------- Stage 1 filters ------------------------------
def in_preferred_location(loc):
    return any(h in loc for h in PREFERRED_LOCATIONS)

elim = pd.DataFrame(index=feat.index)

# 1. Location: reject if NOT in preferred hubs AND NOT willing to relocate
elim["loc_reject"] = (
    ~feat["location"].apply(in_preferred_location) & ~feat["willing_to_relocate"]
)

# 2. AI/ML evidence: reject if NO skill AND NO title AND NO career evidence
elim["no_ai_evidence"] = ~(
    feat["has_relevant_skill"] | feat["title_relevant"] | feat["career_evidence"]
)

# 3. Extreme job-hopping (only when >=3 companies)
elim["job_hopper"] = (feat["total_companies"] >= 3) & (feat["short_switch_ratio"] > 0.7)

# 4. Consulting-only career
elim["consulting_only"] = feat["all_consulting"]

# 5. Entire career non-tech
elim["non_tech"] = feat["non_tech_all"]

# 6. Pure research without production (optional)
elim["pure_research"] = (feat["research_ratio"] >= 0.999) & (~feat["production_evidence"])

elim["eliminated"] = elim.any(axis=1)

# ---- funnel report ----
print("=== STAGE 1: DIRECT ELIMINATIONS ===\n")
print(f"{'Total pool':35s}: {len(feat):>7,}")
for col, label in [
    ("loc_reject", "Rejected: location"),
    ("no_ai_evidence", "Rejected: no AI/ML evidence"),
    ("job_hopper", "Rejected: extreme job-hopping"),
    ("consulting_only", "Rejected: consulting-only"),
    ("non_tech", "Rejected: entire-career non-tech"),
    ("pure_research", "Rejected: pure research"),
]:
    print(f"  {label:33s}: {elim[col].sum():>7,}")

survivors = feat[~elim["eliminated"]].copy()
print(f"\n{'SURVIVORS -> Stage 2':35s}: {len(survivors):>7,}  "
      f"({len(survivors)/len(feat)*100:.1f}% of pool)")
# Out:
# === STAGE 1: DIRECT ELIMINATIONS ===
#
# Total pool                         : 100,000
#   Rejected: location               :  53,437
#   Rejected: no AI/ML evidence      :   3,941
#   Rejected: extreme job-hopping    :     677
#   Rejected: consulting-only        :   9,750
#   Rejected: entire-career non-tech :   1,402
#   Rejected: pure research          :       0
#
# SURVIVORS -> Stage 2               :  40,240  (40.2% of pool)

# %% [markdown]
# ## Stage 2 — Candidate Scoring
#
# Every survivor receives sub-scores in **[0, 1]**, combined via the weighted
# average in `WEIGHTS`, then multiplied by a CV/Robotics/Speech **penalty
# multiplier**. Sub-scores:
#
# - **A. Location** &nbsp; **B. Behavioral** &nbsp; **C. Experience** &nbsp; **D. JD Alignment (hybrid)**
# - **E. Production Evidence** &nbsp; **F. Like-to-Have Bonus** &nbsp; **G. CV/Robotics/Speech Penalty**

# %%
# =================== A. LOCATION SCORE ====================================
def location_score(row):
    loc, country, relo = row["location"], row["country"], row["willing_to_relocate"]
    if any(h in loc for h in PREFERRED_PRIMARY):
        return 1.00
    if any(h in loc for h in PREFERRED_SECONDARY):
        return 0.95
    if "india" in country:
        return 0.80 if relo else 0.60
    # outside India
    return 0.40 if relo else 0.20

# =================== B. BEHAVIORAL SCORE ==================================
def _notice_score(days):
    if days is None or (isinstance(days, float) and np.isnan(days)):
        return 0.5
    if days <= 30:  return 1.00
    if days <= 60:  return 0.85
    if days <= 90:  return 0.60
    if days <= 120: return 0.30
    return 0.10

def _recency_score(days):
    # more recent activity -> higher. ~exponential decay over ~180 days.
    if days is None or (isinstance(days, float) and np.isnan(days)):
        return 0.4
    return float(np.clip(np.exp(-days / 120.0), 0.0, 1.0))

def behavioral_score(row):
    otw = 1.0 if row["open_to_work"] else 0.0
    rec = _recency_score(row["days_since_active"])
    rr = row["recruiter_response_rate"]
    rr = float(rr) if rr is not None and not pd.isna(rr) else 0.5
    ic = row["interview_completion_rate"]
    ic = float(ic) if ic is not None and not pd.isna(ic) else 0.5
    notice = _notice_score(row["notice_period_days"])
    # weighted blend (open-to-work + recency are very high priority)
    return (0.28 * otw + 0.27 * rec + 0.18 * rr + 0.12 * ic + 0.15 * notice)

# =================== C. EXPERIENCE SCORE ==================================
def _applied_ai_score(y):
    if y < 1:   return 0.00
    if y < 2:   return 0.20
    if y < 3:   return 0.40
    if y < 4:   return 0.70
    if y <= 5:  return 1.00
    if y <= 7:  return 0.90
    if y <= 10: return 0.75
    return 0.55

def _total_exp_score(y):
    if y is None or np.isnan(y): return 0.3
    if y < 3:   return 0.00
    if y < 5:   return 0.60
    if y <= 9:  return 1.00
    if y <= 15: return 0.80
    return 0.60

def experience_score(row):
    a = _applied_ai_score(row["applied_ai_years"])
    t = _total_exp_score(row["years_of_experience"])
    # applied-AI experience weighted higher than raw total experience
    return 0.6 * a + 0.4 * t

# =================== E. PRODUCTION EVIDENCE SCORE =========================
def production_score(row):
    blob = row["career_text"] + " " + row["summary"]
    hits = count_kw(blob, PRODUCTION_KEYWORDS)
    # saturate: 0 hits -> 0, 4+ distinct production cues -> 1.0
    return float(np.clip(hits / 4.0, 0.0, 1.0))

# =================== F. LIKE-TO-HAVE BONUS ================================
def like_to_have_score(row):
    blob = row["full_text"]
    groups_hit = sum(1 for kws in LIKE_TO_HAVE.values() if any_kw(blob, kws))
    return float(np.clip(groups_hit / len(LIKE_TO_HAVE), 0.0, 1.0))

# =================== G. CV/ROBOTICS/SPEECH PENALTY ========================
def domain_penalty(row):
    """Return (multiplier<=1.0, reason). Penalize off-domain specialists who
    show strong CV/Speech/Robotics focus but ~no IR/ranking evidence."""
    blob = row["full_text"]
    ir = count_kw(blob, IR_CORE_KEYWORDS)
    cv = count_kw(blob, CV_KEYWORDS)
    sp = count_kw(blob, SPEECH_KEYWORDS)
    ro = count_kw(blob, ROBOTICS_KEYWORDS)
    off_domain = max(cv, sp, ro)
    if ir == 0 and off_domain >= 2:
        return 0.65, "off-domain (CV/Speech/Robotics) focus, no IR evidence"
    if ir == 0 and off_domain == 1:
        return 0.85, "limited IR evidence, some off-domain focus"
    return 1.0, ""

print("Scoring functions A/B/C/E/F/G defined.")
# Out:
# Scoring functions A/B/C/E/F/G defined.

# %%
# =================== D. JD ALIGNMENT (HYBRID RETRIEVAL) ===================
# Phase 1: BM25 + TF-IDF for ALL survivors (fast, no model needed).
# Phase 2 (late-stage): Dense embeddings only for the top DENSE_SHORTLIST_N
#          candidates — avoids encoding tens-of-thousands unnecessarily.

# Positive JD representation: what an ideal candidate looks like.
JD_QUERY = (
    "senior ai engineer building production embeddings based retrieval and ranking "
    "systems for search and recommendation. strong python, vector databases such as "
    "pinecone weaviate qdrant milvus faiss elasticsearch opensearch. semantic search, "
    "information retrieval, learning to rank, bm25, re-ranking, relevance. fine-tuning "
    "large language models, llm, rag, transformers, sentence embeddings, hugging face. "
    "evaluation frameworks ndcg mrr map precision recall, offline and online a/b testing. "
    "deployed scalable low-latency machine learning pipelines to production serving users. "
    "mlops, model serving, monitoring, feature engineering."
)

_token_re = re.compile(r"[a-z0-9#+.]+")
def tokenize(text):
    return _token_re.findall(text)

surv_ids = survivors.index.tolist()
docs = survivors["full_text"].tolist()

def _minmax(arr):
    arr = np.asarray(arr, dtype=float)
    lo, hi = arr.min(), arr.max()
    return (arr - lo) / (hi - lo) if hi > lo else np.zeros_like(arr)

components = {}

# --- (1) TF-IDF cosine (always available via scikit-learn) ---
try:
    from sklearn.feature_extraction.text import TfidfVectorizer
    from sklearn.metrics.pairwise import cosine_similarity
    tfidf = TfidfVectorizer(ngram_range=(1, 2), min_df=2, max_features=50000,
                            sublinear_tf=True, stop_words="english")
    doc_mat = tfidf.fit_transform(docs)
    q_mat = tfidf.transform([JD_QUERY])
    tfidf_sim = cosine_similarity(q_mat, doc_mat).ravel()
    components["tfidf"] = _minmax(tfidf_sim)
    print(f"TF-IDF cosine computed for {len(docs):,} docs.")
except Exception as e:
    print("TF-IDF unavailable:", e)

# --- (2) BM25 (rank_bm25) ---
try:
    from rank_bm25 import BM25Okapi
    tokenized = [tokenize(d) for d in docs]
    bm25 = BM25Okapi(tokenized)
    bm25_scores = bm25.get_scores(tokenize(JD_QUERY))
    components["bm25"] = _minmax(bm25_scores)
    print("BM25 computed.")
except Exception as e:
    print("BM25 unavailable:", e)

# --- Phase 1 blend: BM25 + TF-IDF (all survivors) ---
phase1_weights = {"bm25": 0.5, "tfidf": 0.5}
present_p1 = {k: v for k, v in components.items() if k in phase1_weights}
wsum_p1 = sum(phase1_weights[k] for k in present_p1)
jd_align_p1 = np.zeros(len(docs))
for k, v in present_p1.items():
    jd_align_p1 += (phase1_weights[k] / wsum_p1) * v

survivors["score_jd_alignment"] = jd_align_p1
print(f"\nPhase 1 (BM25+TF-IDF) JD alignment computed for ALL {len(survivors):,} survivors.")
print(survivors["score_jd_alignment"].describe())
# Out:
# TF-IDF cosine computed for 40,240 docs.
# BM25 computed.
#
# Phase 1 (BM25+TF-IDF) JD alignment computed for ALL 40,240 survivors.
# count    40240.000000
# mean         0.088046
# std          0.085702
# min          0.000000
# 25%          0.037373
# 50%          0.056919
# 75%          0.103737
# max          1.000000
# Name: score_jd_alignment, dtype: float64

# %%
# ---- Blend JD-alignment with explicit retrieval/eval/LLM keyword evidence ----
def jd_keyword_evidence(row):
    blob = row["full_text"]
    r = min(count_kw(blob, RETRIEVAL_SIGNALS) / 4.0, 1.0)
    e = min(count_kw(blob, EVAL_SIGNALS) / 3.0, 1.0)
    l = min(count_kw(blob, LLM_SIGNALS) / 3.0, 1.0)
    # retrieval is the core competency for this role
    return 0.5 * r + 0.25 * e + 0.25 * l

survivors["jd_keyword_evidence"] = survivors.apply(jd_keyword_evidence, axis=1)
# 80% semantic similarity + 20% explicit signal evidence
survivors["score_jd_alignment"] = (
    0.8 * survivors["score_jd_alignment"] + 0.2 * survivors["jd_keyword_evidence"]
)

# ---- Compute remaining sub-scores ----
survivors["score_location"]   = survivors.apply(location_score, axis=1)
survivors["score_behavioral"] = survivors.apply(behavioral_score, axis=1)
survivors["score_experience"] = survivors.apply(experience_score, axis=1)
survivors["score_production"] = survivors.apply(production_score, axis=1)
survivors["score_like_to_have"] = survivors.apply(like_to_have_score, axis=1)

_pen = survivors.apply(domain_penalty, axis=1)
survivors["penalty_mult"] = _pen.apply(lambda x: x[0])
survivors["penalty_reason"] = _pen.apply(lambda x: x[1])

# ---- Preliminary weighted aggregation (Phase 1 — no dense embeddings yet) ----
base = (
    WEIGHTS["jd_alignment"] * survivors["score_jd_alignment"]
    + WEIGHTS["experience"]   * survivors["score_experience"]
    + WEIGHTS["behavioral"]   * survivors["score_behavioral"]
    + WEIGHTS["production"]    * survivors["score_production"]
    + WEIGHTS["location"]     * survivors["score_location"]
    + WEIGHTS["like_to_have"] * survivors["score_like_to_have"]
)
survivors["base_score"] = base
survivors["final_score"] = base * survivors["penalty_mult"]

print("Phase 1 sub-scores + preliminary final score computed.")
print(f"Candidates scored: {len(survivors):,}")
score_cols = [c for c in survivors.columns if c.startswith("score_")] + ["penalty_mult", "final_score"]
survivors[score_cols].describe().round(3)
# Out:
# Phase 1 sub-scores + preliminary final score computed.
# Candidates scored: 40,240
#        score_jd_alignment  score_location  score_behavioral  score_experience  \
# count           40240.000       40240.000         40240.000         40240.000
# mean                0.127           0.828             0.467             0.653
# std                 0.102           0.197             0.165             0.272
# min                 0.025           0.400             0.103             0.000
# 25%                 0.059           0.800             0.336             0.480
# 50%                 0.102           0.950             0.435             0.770
# 75%                 0.145           0.950             0.600             0.860
# max                 1.000           1.000             0.964             1.000
#
#        score_production  score_like_to_have  penalty_mult  final_score
# count         40240.000           40240.000     40240.000    40240.000
# mean              0.361               0.226         0.925        0.369
# std               0.291               0.112         0.088        0.100
# min               0.000               0.000         0.650        0.064
# 25%               0.250               0.200         0.850        0.305
# 50%               0.250               0.200         1.000        0.369
# 75%               0.500               0.200         1.000        0.427
# max               1.000               0.800         1.000        0.921

# %%
# =================== Phase 2: Late-Stage Dense Embeddings =================
# Only encode the top DENSE_SHORTLIST_N candidates (by preliminary score).
# This keeps the expensive embedding step fast and memory-light.

if USE_DENSE_EMBEDDINGS:
    shortlist_ids = survivors.nlargest(DENSE_SHORTLIST_N, "final_score").index.tolist()
    shortlist_docs = survivors.loc[shortlist_ids, "full_text"].tolist()
    print(f"Dense embedding shortlist: {len(shortlist_ids)} candidates")

    dense_applied = False
    try:
        from sentence_transformers import SentenceTransformer
        st_model = SentenceTransformer(EMBED_MODEL)
        emb = st_model.encode(shortlist_docs, batch_size=64, show_progress_bar=True,
                              normalize_embeddings=True)
        q_emb = st_model.encode([JD_QUERY], normalize_embeddings=True)
        dense_sim = (emb @ q_emb.T).ravel()
        dense_norm = _minmax(dense_sim)

        # Re-compute JD alignment for shortlisted candidates with dense component
        # Blend: 40% dense + 30% BM25 + 15% TF-IDF + 15% keyword evidence
        shortlist_tfidf = survivors.loc[shortlist_ids, "score_jd_alignment"].values
        shortlist_kw = survivors.loc[shortlist_ids, "jd_keyword_evidence"].values

        # Retrieve BM25 component for shortlisted candidates
        surv_id_to_idx = {cid: i for i, cid in enumerate(surv_ids)}
        shortlist_bm25 = np.array([components.get("bm25", np.zeros(len(surv_ids)))[surv_id_to_idx[cid]]
                                   for cid in shortlist_ids])
        shortlist_tfidf_raw = np.array([components.get("tfidf", np.zeros(len(surv_ids)))[surv_id_to_idx[cid]]
                                        for cid in shortlist_ids])

        # New blended JD alignment for shortlist
        jd_align_v2 = (0.40 * dense_norm
                       + 0.25 * _minmax(shortlist_bm25)
                       + 0.15 * _minmax(shortlist_tfidf_raw)
                       + 0.20 * shortlist_kw)

        survivors.loc[shortlist_ids, "score_jd_alignment"] = jd_align_v2
        dense_applied = True
        print("Dense embeddings applied to shortlist. Re-scoring...")
    except Exception as e:
        print(f"Dense embeddings unavailable ({e}) — keeping Phase 1 scores.")

    if dense_applied:
        # Recompute final_score for the shortlisted candidates
        for cid in shortlist_ids:
            row = survivors.loc[cid]
            b = (
                WEIGHTS["jd_alignment"] * row["score_jd_alignment"]
                + WEIGHTS["experience"]   * row["score_experience"]
                + WEIGHTS["behavioral"]   * row["score_behavioral"]
                + WEIGHTS["production"]    * row["score_production"]
                + WEIGHTS["location"]     * row["score_location"]
                + WEIGHTS["like_to_have"] * row["score_like_to_have"]
            )
            survivors.loc[cid, "base_score"] = b
            survivors.loc[cid, "final_score"] = b * row["penalty_mult"]
        print(f"Re-scored {len(shortlist_ids)} candidates with dense embeddings.")
else:
    print("Dense embeddings disabled (USE_DENSE_EMBEDDINGS=False). Using BM25+TF-IDF only.")

print(f"\nFinal score stats (top {DENSE_SHORTLIST_N} by preliminary rank):")
print(survivors.nlargest(DENSE_SHORTLIST_N, "final_score")["final_score"].describe().round(4))
# Out:
# Dense embedding shortlist: 500 candidates
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 6866.18it/s]
# Batches: 100%|██████████| 8/8 [00:15<00:00,  1.92s/it]
# Dense embeddings applied to shortlist. Re-scoring...
# Re-scored 500 candidates with dense embeddings.
#
# Final score stats (top 500 by preliminary rank):
# count    500.0000
# mean       0.7065
# std        0.0520
# min        0.6327
# 25%        0.6653
# 50%        0.6992
# 75%        0.7419
# max        0.9235
# Name: final_score, dtype: float64

# %% [markdown]
# ## Stage 3 — Honeypot Detection
#
# Honeypots are impossible/contradictory profiles. We **reject** on strong
# evidence and **penalize** when uncertain (configurable). Detectors:
#
# - Expert skill claimed with ~zero usage duration (multiple times)
# - Stated experience vs summed career tenure mismatch (impossible timelines)
# - Title inflation / contradictory seniority vs tenure
# - Implausible breadth of expert skills (keyword stuffing)
#
# > Honeypot rate **> 10%** in the final top 100 = disqualification, so we screen the
# > shortlist before locking it in.

# %%
# --------------------------- Honeypot scoring -----------------------------
# If uncertainty exists, we apply a penalty rather than a hard reject.
HONEYPOT_REJECT_THRESHOLD = 3   # cumulative suspicion points -> hard reject

def honeypot_flags(row):
    flags, points = [], 0

    # H1: multiple expert skills with ~zero duration -> strong
    if row["expert_zero_dur"] >= 3:
        flags.append("3+ expert skills with ~0 months usage"); points += 3
    elif row["expert_zero_dur"] == 2:
        flags.append("2 expert skills with ~0 months usage"); points += 2

    # H2: implausible number of expert skills (stuffing)
    if row["n_expert"] >= 10:
        flags.append(f"{row['n_expert']} expert skills (implausible breadth)"); points += 2

    # H3: stated experience vs summed career tenure mismatch
    yoe = row["years_of_experience"]
    career_years = row["total_months"] / 12.0
    if yoe is not None and not np.isnan(yoe) and career_years > 0:
        gap = abs(yoe - career_years)
        if gap > 8:
            flags.append(f"exp/tenure mismatch ({yoe:.0f}y stated vs {career_years:.0f}y career)"); points += 3
        elif gap > 5:
            flags.append(f"exp/tenure gap ({gap:.0f}y)"); points += 1

    # H4: title inflation — senior/lead/staff title with very little total tenure
    title = row["current_title"]
    if any(k in title for k in ["senior", "lead", "staff", "principal", "head"]) and career_years < 2:
        flags.append("senior-level title with <2y total tenure"); points += 2

    return points, "; ".join(flags)

_hp = survivors.apply(honeypot_flags, axis=1)
survivors["honeypot_points"] = _hp.apply(lambda x: x[0])
survivors["honeypot_reason"] = _hp.apply(lambda x: x[1])
survivors["is_honeypot"] = survivors["honeypot_points"] >= HONEYPOT_REJECT_THRESHOLD

# Soft penalty for uncertain (1-2 points): scale final score down a little
soft = survivors["honeypot_points"].between(1, HONEYPOT_REJECT_THRESHOLD - 1)
survivors.loc[soft, "final_score"] *= 0.90

print("=== STAGE 3: HONEYPOT DETECTION ===")
print(f"Hard-rejected honeypots:      {survivors['is_honeypot'].sum():,}")
print(f"Soft-penalized (uncertain):   {soft.sum():,}")

clean = survivors[~survivors["is_honeypot"]].copy()
print(f"Clean candidates remaining:   {len(clean):,}")
# Out:
# === STAGE 3: HONEYPOT DETECTION ===
# Hard-rejected honeypots:      21
# Soft-penalized (uncertain):   12
# Clean candidates remaining:   40,219

# %% [markdown]
# ## Final Selection &amp; Reasoning Generation
#
# Sort by `final_score` (descending) and take the **Top 100**. Then generate a
# concise, candidate-specific explanation citing the strongest contributors, one
# limitation, and a link to JD requirements.

# %%
# ----------------------------- Select Top 100 -----------------------------
top = clean.sort_values("final_score", ascending=False).head(TOP_N).copy()
top["rank"] = range(1, len(top) + 1)

# safety: confirm there is no honeypot leakage in the shortlist
hp_in_top = top["is_honeypot"].sum()
print(f"Top {len(top)} selected. Honeypots in shortlist: {hp_in_top} "
      f"({hp_in_top/len(top)*100:.1f}%) — must stay < 10%.")
# Out:
# Top 100 selected. Honeypots in shortlist: 0 (0.0%) — must stay < 10%.

# %%
# --------------------------- Reasoning generation -------------------------
# Human-readable phrases keyed by sub-score, weighted by importance.
STRENGTH_PHRASES = {
    "score_jd_alignment": lambda r: "strong semantic fit to the retrieval/ranking JD",
    "score_experience":   lambda r: f"{r['applied_ai_years']:.0f}y applied-AI experience"
                                     f" ({r['years_of_experience']:.0f}y total)",
    "score_production":   lambda r: "demonstrated production ML deployment",
    "score_behavioral":   lambda r: ("actively open to work and recently engaged"
                                      if r["open_to_work"] else "engaged recruiter signals"),
    "score_location":     lambda r: f"based in a preferred hub ({r['location'].title()})"
                                     if any(h in r['location'] for h in PREFERRED_LOCATIONS)
                                     else "geographically workable",
    "score_like_to_have": lambda r: "bonus depth (fine-tuning / LTR / OSS)",
}

def concern_phrase(r):
    # pick the weakest meaningful sub-score as the limitation
    subs = {
        "applied-AI depth": r["score_experience"],
        "production evidence": r["score_production"],
        "JD/domain alignment": r["score_jd_alignment"],
        "availability signals": r["score_behavioral"],
    }
    weakest = min(subs, key=subs.get)
    if r["penalty_reason"]:
        return f"concern: {r['penalty_reason']}"
    if r["honeypot_reason"]:
        return f"minor flag: {r['honeypot_reason']}"
    if subs[weakest] < 0.5:
        return f"limited {weakest}"
    if r["notice_period_days"] and r["notice_period_days"] > 60:
        return f"longer notice period (~{int(r['notice_period_days'])}d)"
    return "no major concerns; verify depth in interview"

# rotate sentence templates to avoid identical structure
TEMPLATES = [
    "Ranked #{rank}: {s1} and {s2}, with {s3}. {concern}.",
    "#{rank} — {s1}; also {s2}. Notably {s3}. {concern}.",
    "Selected (#{rank}) for {s1} plus {s2}. {s3.capitalize}. {concern}.",
    "#{rank}: combines {s1} with {s2} and {s3}. {concern}.",
]

def make_reasoning(cid, r, rank):
    # rank sub-scores by weighted contribution to pick top strengths
    contrib = {k: WEIGHTS[k.replace("score_", "")] * r[k] for k in STRENGTH_PHRASES}
    ordered = sorted(contrib, key=contrib.get, reverse=True)
    phrases = [STRENGTH_PHRASES[k](r) for k in ordered[:3]]
    tmpl = TEMPLATES[rank % len(TEMPLATES)]
    text = (tmpl
            .replace("{rank}", str(rank))
            .replace("{s1}", phrases[0])
            .replace("{s2}", phrases[1])
            .replace("{s3.capitalize}", phrases[2].capitalize())
            .replace("{s3}", phrases[2])
            .replace("{concern}", concern_phrase(r)))
    # collapse whitespace and tidy
    return re.sub(r"\s+", " ", text).strip()

top["reasoning"] = [make_reasoning(cid, row, row["rank"]) for cid, row in top.iterrows()]

# preview
for cid, row in top.head(5).iterrows():
    print(f"[{row['rank']:>3}] {cid}  score={row['final_score']:.4f}")
    print("     ", row["reasoning"], "\n")
# Out:
# [  1] CAND_0046525  score=0.9150
#       #1 — strong semantic fit to the retrieval/ranking JD; also 6y applied-AI experience (6y total). Notably demonstrated production ML deployment. no major concerns; verify depth in interview.
#
# [  2] CAND_0018499  score=0.9019
#       Selected (#2) for strong semantic fit to the retrieval/ranking JD plus 7y applied-AI experience (7y total). Demonstrated production ml deployment. no major concerns; verify depth in interview.
#
# [  3] CAND_0086022  score=0.8558
#       #3: combines strong semantic fit to the retrieval/ranking JD with 5y applied-AI experience (5y total) and demonstrated production ML deployment. no major concerns; verify depth in interview.
#
# [  4] CAND_0081846  score=0.8312
#       Ranked #4: strong semantic fit to the retrieval/ranking JD and 7y applied-AI experience (7y total), with demonstrated production ML deployment. minor flag: 10 expert skills (implausible breadth).
#
# [  5] CAND_0096142  score=0.8283
#       #5 — strong semantic fit to the retrieval/ranking JD; also 5y applied-AI experience (5y total). Notably demonstrated production ML deployment. longer notice period (~120d).

# %%
# ----------------------------- Write submission ---------------------------
submission = top.reset_index()[["candidate_id", "rank", "final_score", "reasoning"]].copy()
submission = submission.rename(columns={"final_score": "score"})

# round score for readability; ensure monotonically non-increasing by rank
submission["score"] = submission["score"].round(6)
submission = submission.sort_values("rank").reset_index(drop=True)
assert submission["score"].is_monotonic_decreasing or \
       (submission["score"].diff().dropna() <= 0).all(), "scores must be non-increasing"
assert len(submission) == TOP_N, f"expected {TOP_N} rows, got {len(submission)}"

submission.to_csv(OUTPUT_CSV, index=False)
print(f"Wrote {OUTPUT_CSV} with {len(submission)} rows.")
print(f"Total pipeline time: {time.time()-t0:.1f}s")
submission.head(10)
# Out:
# Wrote submission.csv with 100 rows.
# Total pipeline time: 333.5s
#    candidate_id  rank     score  \
# 0  CAND_0046525     1  0.914968
# 1  CAND_0018499     2  0.901859
# 2  CAND_0086022     3  0.855761
# 3  CAND_0081846     4  0.831153
# 4  CAND_0096142     5  0.828269
# 5  CAND_0069905     6  0.827291
# 6  CAND_0027691     7  0.825472
# 7  CAND_0061265     8  0.816443
# 8  CAND_0005260     9  0.815574
# 9  CAND_0054394    10  0.815196
#
#                                            reasoning
# 0  #1 — strong semantic fit to the retrieval/rank...
# 1  Selected (#2) for strong semantic fit to the r...
# 2  #3: combines strong semantic fit to the retrie...
# 3  Ranked #4: strong semantic fit to the retrieva...
# 4  #5 — strong semantic fit to the retrieval/rank...
# 5  Selected (#6) for strong semantic fit to the r...
# 6  #7: combines strong semantic fit to the retrie...
# 7  Ranked #8: strong semantic fit to the retrieva...
# 8  #9 — strong semantic fit to the retrieval/rank...
# 9  Selected (#10) for strong semantic fit to the ...

# %%
# --------------------------- Sanity / QA report ---------------------------
print("=== TOP 100 QA SUMMARY ===")
print(f"Score range:        {top['final_score'].min():.4f} -> {top['final_score'].max():.4f}")
print(f"Honeypots in top:   {top['is_honeypot'].sum()} (DQ if >10)")
print(f"\nLocation mix (top 100):")
print(top['location'].apply(lambda l: next((h for h in PREFERRED_LOCATIONS if h in l), 'other/relocate')).value_counts().to_string())
print(f"\nYears of experience (top 100):")
print(top['years_of_experience'].describe().round(1).to_string())
print(f"\nApplied-AI years (top 100):")
print(top['applied_ai_years'].describe().round(1).to_string())
print(f"\nMean sub-scores (top 100):")
print(top[[c for c in top.columns if c.startswith('score_')]].mean().round(3).to_string())
# Out:
# === TOP 100 QA SUMMARY ===
# Score range:        0.7495 -> 0.9150
# Honeypots in top:   0 (DQ if >10)
#
# Location mix (top 100):
# location
# other/relocate    45
# noida             16
# pune              10
# gurgaon            9
# delhi              8
# hyderabad          7
# mumbai             5
#
# Years of experience (top 100):
# count    100.0
# mean       6.2
# std        1.1
# min        3.0
# 25%        5.4
# 50%        6.2
# 75%        6.9
# max        8.6
#
# Applied-AI years (top 100):
# count    100.0
# mean       6.1
# std        1.0
# min        3.1
# 25%        5.3
# 50%        6.2
# 75%        6.8
# max        8.4
#
# Mean sub-scores (top 100):
# score_jd_alignment    0.676
# score_location        0.880
# score_behavioral      0.775
# score_experience      0.909
# score_production      0.980
# score_like_to_have    0.468

# %%
# ========================= TOP 100 CANDIDATE DETAILS ======================
# Rich per-candidate view: scores, profile info, signals, and reasoning.

pd.set_option("display.max_colwidth", 120)
pd.set_option("display.max_rows", 200)

# ---- Compact detail table (all 100 rows) ----------------------------------
detail_cols = [
    "rank",
    "current_title",
    "location",
    "years_of_experience",
    "applied_ai_years",
    "final_score",
    "score_jd_alignment",
    "score_experience",
    "score_production",
    "score_behavioral",
    "score_location",
    "score_like_to_have",
    "penalty_mult",
    "open_to_work",
    "notice_period_days",
    "github_activity_score",
    "profile_completeness_score",
    "honeypot_points",
    "reasoning",
]
detail = top[detail_cols].sort_values("rank").reset_index()
detail.columns = [c.replace("score_", "").replace("_", " ").title() for c in detail.columns]

print(f"{'='*80}")
print(f"  TOP {len(top)} CANDIDATES — FULL DETAIL VIEW")
print(f"{'='*80}\n")
display(detail)

# ---- Verbose per-candidate card (top 20 to keep output manageable) --------
print(f"\n{'='*80}")
print("  CANDIDATE CARDS  (top 20 — adjust slice as needed)")
print(f"{'='*80}")

for _, row in top.sort_values("rank").head(20).iterrows():
    cid = row.name
    skills_preview = ", ".join(row["skill_names"][:10]) if row["skill_names"] else "—"
    print(f"""
┌─ #{int(row['rank']):>3}  {cid}  (final={row['final_score']:.4f})
│  Title     : {row['current_title'].title()}
│  Location  : {row['location'].title()} | Relocate: {row['willing_to_relocate']}
│  Experience: {row['years_of_experience']:.0f}y total / {row['applied_ai_years']:.1f}y applied-AI
│  Company   : {row['current_company'].title()}  |  Industry: {row['current_industry'].title()}
│  Open2Work : {row['open_to_work']}  |  Notice: {int(row['notice_period_days']) if pd.notna(row['notice_period_days']) else 'N/A'}d  |  GitHub: {row['github_activity_score']}
│  Sub-scores: JD={row['score_jd_alignment']:.3f}  Exp={row['score_experience']:.3f}  Prod={row['score_production']:.3f}  Behav={row['score_behavioral']:.3f}  Loc={row['score_location']:.3f}  LTH={row['score_like_to_have']:.3f}  Penalty×{row['penalty_mult']:.2f}
│  Skills    : {skills_preview}
│  Reasoning : {row['reasoning']}
└{'─'*78}""")
# Out:
# ================================================================================
#   TOP 100 CANDIDATES — FULL DETAIL VIEW
# ================================================================================
#     Candidate Id  Rank                     Current Title  \
# 0   CAND_0046525     1  senior machine learning engineer
# 1   CAND_0018499     2  senior machine learning engineer
# 2   CAND_0086022     3          senior applied scientist
# 3   CAND_0081846     4                  lead ai engineer
# 4   CAND_0096142     5               applied ml engineer
# 5   CAND_0069905     6               applied ml engineer
# 6   CAND_0027691     7                      nlp engineer
# 7   CAND_0061265     8   recommendation systems engineer
# 8   CAND_0005260     9               senior nlp engineer
# 9   CAND_0054394    10   recommendation systems engineer
# 10  CAND_0040178    11                       ml engineer
# 11  CAND_0018549    12   recommendation systems engineer
# 12  CAND_0091909    13         machine learning engineer
# 13  CAND_0041669    14   recommendation systems engineer
# 14  CAND_0068811    15               applied ml engineer
# 15  CAND_0041610    16   recommendation systems engineer
# 16  CAND_0094759    17                  lead ai engineer
# 17  CAND_0052328    18   recommendation systems engineer
# 18  CAND_0070525    19     senior software engineer (ml)
# 19  CAND_0005649    20             senior data scientist
# 20  CAND_0006418    21         machine learning engineer
# 21  CAND_0081053    22                      nlp engineer
# 22  CAND_0011327    23              ai research engineer
# 23  CAND_0006557    24                      nlp engineer
# 24  CAND_0053605    25     senior software engineer (ml)
# 25  CAND_0067866    26     senior software engineer (ml)
# 26  CAND_0054123    27               applied ml engineer
# 27  CAND_0058575    28                       ai engineer
# 28  CAND_0030348    29         machine learning engineer
# 29  CAND_0044855    30             senior data scientist
# 30  CAND_0083879    31         machine learning engineer
# 31  CAND_0026532    32   recommendation systems engineer
# 32  CAND_0001610    33         machine learning engineer
# 33  CAND_0006538    34                     ai specialist
# 34  CAND_0049896    35                   search engineer
# 35  CAND_0062247    36                       ai engineer
# 36  CAND_0077337    37   staff machine learning engineer
# 37  CAND_0043860    38                junior ml engineer
# 38  CAND_0011162    39   recommendation systems engineer
# 39  CAND_0060315    40     senior software engineer (ml)
# 40  CAND_0007460    41                       ai engineer
# 41  CAND_0081852    42             senior data scientist
# 42  CAND_0009691    43               applied ml engineer
# 43  CAND_0076251    44                   search engineer
# 44  CAND_0098454    45                     ai specialist
# 45  CAND_0061257    46   staff machine learning engineer
# 46  CAND_0027801    47                      nlp engineer
# 47  CAND_0005509    48                    data scientist
# 48  CAND_0057563    49                      nlp engineer
# 49  CAND_0008295    50              ai research engineer
# 50  CAND_0072688    51                    data scientist
# 51  CAND_0064326    52                   search engineer
# 52  CAND_0043637    53                junior ml engineer
# 53  CAND_0086151    54   recommendation systems engineer
# 54  CAND_0075574    55         machine learning engineer
# 55  CAND_0008517    56              ai research engineer
# 56  CAND_0066376    57               applied ml engineer
# 57  CAND_0010541    58              ai research engineer
# 55                   11.7                        63.9                0
# 56                   -1.0                        62.8                2
# 57                   18.2                        75.3                0
# 58                   -1.0                        93.4                0
# 59                   28.0                        61.9                0
# 60                   35.2                        58.6                0
# 61                   20.9                        73.9                0
# 62                   75.2                        99.8                0
# 63                   23.2                        50.1                0
# 64                   31.7                        97.3                0
# 65                   21.3                        92.6                0
# 66                   59.0                        69.6                0
# 67                   -1.0                        85.5                0
# 68                   45.5                        85.1                0
# 69                   95.0                        89.5                0
# 70                   36.0                        81.3                0
# 71                   47.2                        63.1                0
# 72                   26.8                        77.4                0
# 73                   70.5                        95.3                0
# 74                   17.4                        86.4                0
# 75                   39.5                        55.3                0
# 76                   45.4                        74.2                0
# 77                   64.8                        59.8                0
# 78                   38.4                        56.1                0
# 79                   -1.0                        72.8                0
# 80                   54.4                        46.4                0
# 81                   23.7                        67.7                0
# 82                   86.2                        90.0                0
# 83                   63.1                        50.3                0
# 84                   81.3                        76.6                0
# 85                   90.1                        64.6                0
# 86                   55.5                        76.2                0
# 87                   94.3                        63.4                0
# 88                   -1.0                        67.3                0
# 89                   83.1                        95.9                0
# 90                   12.9                        89.0                0
# 91                   -1.0                        62.1                0
# 92                   23.2                        60.1                0
# 93                   82.9                        52.9                0
# 94                   67.1                        92.6                0
# 95                   74.4                        65.2                0
# 96                   94.4                        73.2                0
# 97                   53.5                        73.0                0
# 98                   43.3                        96.7                0
# 99                   66.2                        85.5                0
#
#                                                                                                                   Reasoning
# 0   #1 — strong semantic fit to the retrieval/ranking JD; also 6y applied-AI experience (6y total). Notably demonstrated...
# 1   Selected (#2) for strong semantic fit to the retrieval/ranking JD plus 7y applied-AI experience (7y total). Demonstr...
# 2   #3: combines strong semantic fit to the retrieval/ranking JD with 5y applied-AI experience (5y total) and demonstrat...
# 3   Ranked #4: strong semantic fit to the retrieval/ranking JD and 7y applied-AI experience (7y total), with demonstrate...
# 4   #5 — strong semantic fit to the retrieval/ranking JD; also 5y applied-AI experience (5y total). Notably demonstrated...
# 5   Selected (#6) for strong semantic fit to the retrieval/ranking JD plus 6y applied-AI experience (7y total). Demonstr...
# 6   #7: combines strong semantic fit to the retrieval/ranking JD with 6y applied-AI experience (6y total) and demonstrat...
# 7   Ranked #8: strong semantic fit to the retrieval/ranking JD and 6y applied-AI experience (7y total), with demonstrate...
# 8   #9 — strong semantic fit to the retrieval/ranking JD; also 5y applied-AI experience (5y total). Notably demonstrated...
# 9   Selected (#10) for strong semantic fit to the retrieval/ranking JD plus 4y applied-AI experience (4y total). Demonst...
# 10  #11: combines 5y applied-AI experience (5y total) with strong semantic fit to the retrieval/ranking JD and demonstra...
# 11  Ranked #12: strong semantic fit to the retrieval/ranking JD and 7y applied-AI experience (7y total), with demonstrat...
# 12  #13 — strong semantic fit to the retrieval/ranking JD; also 7y applied-AI experience (7y total). Notably demonstrate...
# 13  Selected (#14) for strong semantic fit to the retrieval/ranking JD plus 8y applied-AI experience (8y total). Demonst...
# 14  #15: combines strong semantic fit to the retrieval/ranking JD with 8y applied-AI experience (8y total) and demonstra...
# 15  Ranked #16: strong semantic fit to the retrieval/ranking JD and 7y applied-AI experience (7y total), with demonstrat...
# 16  #17 — strong semantic fit to the retrieval/ranking JD; also 8y applied-AI experience (9y total). Notably demonstrate...
# 17  Selected (#18) for 6y applied-AI experience (6y total) plus strong semantic fit to the retrieval/ranking JD. Demonst...
# 18  #19: combines 5y applied-AI experience (5y total) with strong semantic fit to the retrieval/ranking JD and demonstra...
# 19  Ranked #20: strong semantic fit to the retrieval/ranking JD and 7y applied-AI experience (7y total), with demonstrat...
# 20  #21 — strong semantic fit to the retrieval/ranking JD; also 6y applied-AI experience (6y total). Notably demonstrate...
# 21  Selected (#22) for strong semantic fit to the retrieval/ranking JD plus 5y applied-AI experience (5y total). Demonst...
# 22  #23: combines 6y applied-AI experience (6y total) with strong semantic fit to the retrieval/ranking JD and demonstra...
# 23  Ranked #24: strong semantic fit to the retrieval/ranking JD and 8y applied-AI experience (8y total), with demonstrat...
# 24  #25 — 7y applied-AI experience (7y total); also strong semantic fit to the retrieval/ranking JD. Notably demonstrate...
# 25  Selected (#26) for 6y applied-AI experience (6y total) plus strong semantic fit to the retrieval/ranking JD. Demonst...
# 26  #27: combines strong semantic fit to the retrieval/ranking JD with 5y applied-AI experience (5y total) and demonstra...
# 27  Ranked #28: strong semantic fit to the retrieval/ranking JD and 6y applied-AI experience (6y total), with demonstrat...
# 28  #29 — strong semantic fit to the retrieval/ranking JD; also 4y applied-AI experience (4y total). Notably demonstrate...
# 29  Selected (#30) for strong semantic fit to the retrieval/ranking JD plus 6y applied-AI experience (7y total). Demonst...
# 30  #31: combines 7y applied-AI experience (7y total) with strong semantic fit to the retrieval/ranking JD and demonstra...
# 31  Ranked #32: strong semantic fit to the retrieval/ranking JD and 5y applied-AI experience (5y total), with demonstrat...
# 32  #33 — strong semantic fit to the retrieval/ranking JD; also 5y applied-AI experience (3y total). Notably demonstrate...
# 33  Selected (#34) for 6y applied-AI experience (6y total) plus strong semantic fit to the retrieval/ranking JD. Demonst...
# 34  #35: combines strong semantic fit to the retrieval/ranking JD with 7y applied-AI experience (7y total) and demonstra...
# 35  Ranked #36: strong semantic fit to the retrieval/ranking JD and 7y applied-AI experience (7y total), with actively o...
# 36  #37 — strong semantic fit to the retrieval/ranking JD; also 7y applied-AI experience (7y total). Notably demonstrate...
# 37  Selected (#38) for 6y applied-AI experience (6y total) plus strong semantic fit to the retrieval/ranking JD. Demonst...
# 38  #39: combines strong semantic fit to the retrieval/ranking JD with 6y applied-AI experience (6y total) and demonstra...
# 39  Ranked #40: strong semantic fit to the retrieval/ranking JD and 5y applied-AI experience (5y total), with demonstrat...
# 40  #41 — strong semantic fit to the retrieval/ranking JD; also 5y applied-AI experience (5y total). Notably demonstrate...
# 41  Selected (#42) for 6y applied-AI experience (6y total) plus strong semantic fit to the retrieval/ranking JD. Demonst...
# 42  #43: combines strong semantic fit to the retrieval/ranking JD with 6y applied-AI experience (6y total) and demonstra...
# 43  Ranked #44: strong semantic fit to the retrieval/ranking JD and 8y applied-AI experience (8y total), with demonstrat...
# 44  #45 — 6y applied-AI experience (7y total); also strong semantic fit to the retrieval/ranking JD. Notably demonstrate...
# 45  Selected (#46) for strong semantic fit to the retrieval/ranking JD plus 8y applied-AI experience (8y total). Demonst...
# 46  #47: combines strong semantic fit to the retrieval/ranking JD with 7y applied-AI experience (7y total) and demonstra...
# 47  Ranked #48: 6y applied-AI experience (6y total) and strong semantic fit to the retrieval/ranking JD, with demonstrat...
# 48  #49 — strong semantic fit to the retrieval/ranking JD; also 7y applied-AI experience (7y total). Notably demonstrate...
# 49  Selected (#50) for 6y applied-AI experience (6y total) plus strong semantic fit to the retrieval/ranking JD. Demonst...
# 50  #51: combines 7y applied-AI experience (7y total) with strong semantic fit to the retrieval/ranking JD and demonstra...
# 51  Ranked #52: strong semantic fit to the retrieval/ranking JD and 8y applied-AI experience (8y total), with actively o...
# 52  #53 — 5y applied-AI experience (6y total); also demonstrated production ML deployment. Notably actively open to work...
# 53  Selected (#54) for strong semantic fit to the retrieval/ranking JD plus 8y applied-AI experience (8y total). Demonst...
# 54  #55: combines strong semantic fit to the retrieval/ranking JD with 6y applied-AI experience (6y total) and actively ...
# 55  Ranked #56: 5y applied-AI experience (6y total) and strong semantic fit to the retrieval/ranking JD, with demonstrat...
# 56  #57 — strong semantic fit to the retrieval/ranking JD; also 6y applied-AI experience (6y total). Notably demonstrate...
# 57  Selected (#58) for 6y applied-AI experience (6y total) plus strong semantic fit to the retrieval/ranking JD. Demonst...
# 58  #59: combines 6y applied-AI experience (6y total) with strong semantic fit to the retrieval/ranking JD and actively ...
# 59  Ranked #60: 6y applied-AI experience (6y total) and strong semantic fit to the retrieval/ranking JD, with demonstrat...
# 60  #61 — strong semantic fit to the retrieval/ranking JD; also 8y applied-AI experience (8y total). Notably demonstrate...
# 61  Selected (#62) for strong semantic fit to the retrieval/ranking JD plus 6y applied-AI experience (6y total). Demonst...
# 62  #63: combines 5y applied-AI experience (5y total) with strong semantic fit to the retrieval/ranking JD and demonstra...
# 63  Ranked #64: strong semantic fit to the retrieval/ranking JD and 8y applied-AI experience (8y total), with demonstrat...
# 64  #65 — 4y applied-AI experience (4y total); also strong semantic fit to the retrieval/ranking JD. Notably demonstrate...
# 65  Selected (#66) for 7y applied-AI experience (7y total) plus strong semantic fit to the retrieval/ranking JD. Demonst...
# 66  #67: combines strong semantic fit to the retrieval/ranking JD with 5y applied-AI experience (5y total) and demonstra...
# 67  Ranked #68: strong semantic fit to the retrieval/ranking JD and 5y applied-AI experience (5y total), with demonstrat...
# 68  #69 — 6y applied-AI experience (6y total); also strong semantic fit to the retrieval/ranking JD. Notably demonstrate...
# 69  Selected (#70) for 7y applied-AI experience (7y total) plus strong semantic fit to the retrieval/ranking JD. Demonst...
# 70  #71: combines strong semantic fit to the retrieval/ranking JD with 7y applied-AI experience (7y total) and demonstra...
# 71  Ranked #72: 5y applied-AI experience (6y total) and strong semantic fit to the retrieval/ranking JD, with demonstrat...
# 72  #73 — strong semantic fit to the retrieval/ranking JD; also 5y applied-AI experience (5y total). Notably actively op...
# 73  Selected (#74) for 5y applied-AI experience (5y total) plus strong semantic fit to the retrieval/ranking JD. Demonst...
# 74  #75: combines 6y applied-AI experience (6y total) with demonstrated production ML deployment and strong semantic fit...
# 75  Ranked #76: 6y applied-AI experience (7y total) and demonstrated production ML deployment, with strong semantic fit ...
# 76  #77 — 6y applied-AI experience (6y total); also strong semantic fit to the retrieval/ranking JD. Notably demonstrate...
# 77  Selected (#78) for strong semantic fit to the retrieval/ranking JD plus 6y applied-AI experience (6y total). Demonst...
# 78  #79: combines strong semantic fit to the retrieval/ranking JD with 6y applied-AI experience (6y total) and demonstra...
# 79  Ranked #80: strong semantic fit to the retrieval/ranking JD and 5y applied-AI experience (5y total), with demonstrat...
# 80  #81 — 5y applied-AI experience (5y total); also strong semantic fit to the retrieval/ranking JD. Notably demonstrate...
# 81  Selected (#82) for 6y applied-AI experience (6y total) plus strong semantic fit to the retrieval/ranking JD. Demonst...
# 82  #83: combines strong semantic fit to the retrieval/ranking JD with 8y applied-AI experience (8y total) and demonstra...
# 83  Ranked #84: strong semantic fit to the retrieval/ranking JD and 7y applied-AI experience (7y total), with demonstrat...
# 84  #85 — 6y applied-AI experience (6y total); also strong semantic fit to the retrieval/ranking JD. Notably demonstrate...
# 85  Selected (#86) for strong semantic fit to the retrieval/ranking JD plus 7y applied-AI experience (7y total). Demonst...
# 86  #87: combines 7y applied-AI experience (7y total) with strong semantic fit to the retrieval/ranking JD and demonstra...
# 87  Ranked #88: strong semantic fit to the retrieval/ranking JD and 6y applied-AI experience (7y total), with demonstrat...
# 88  #89 — strong semantic fit to the retrieval/ranking JD; also 6y applied-AI experience (6y total). Notably demonstrate...
# 89  Selected (#90) for strong semantic fit to the retrieval/ranking JD plus 7y applied-AI experience (7y total). Demonst...
# 90  #91: combines strong semantic fit to the retrieval/ranking JD with demonstrated production ML deployment and 3y appl...
# 91  Ranked #92: 7y applied-AI experience (7y total) and strong semantic fit to the retrieval/ranking JD, with demonstrat...
# 92  #93 — strong semantic fit to the retrieval/ranking JD; also 7y applied-AI experience (7y total). Notably demonstrate...
# 93  Selected (#94) for strong semantic fit to the retrieval/ranking JD plus 5y applied-AI experience (5y total). Demonst...
# 94  #95: combines 6y applied-AI experience (6y total) with demonstrated production ML deployment and actively open to wo...
# 95  Ranked #96: strong semantic fit to the retrieval/ranking JD and 5y applied-AI experience (5y total), with demonstrat...
# 96  #97 — 6y applied-AI experience (6y total); also strong semantic fit to the retrieval/ranking JD. Notably demonstrate...
# ...
# ================================================================================
#
# ┌─ #  1  CAND_0046525  (final=0.9150)
# │  Title     : Senior Machine Learning Engineer
# │  Location  : Pune, Maharashtra | Relocate: True
# │  Experience: 6y total / 6.1y applied-AI
# │  Company   : Genpact Ai  |  Industry: Ai Services
# │  Open2Work : True  |  Notice: 60d  |  GitHub: 36.7
# │  Sub-scores: JD=0.928  Exp=0.940  Prod=1.000  Behav=0.924  Loc=1.000  LTH=0.600  Penalty×1.00
# │  Skills    : elasticsearch, redux, langchain, machine learning, llamaindex, information retrieval, tensorflow, llms, nlp, sentence transformers
# │  Reasoning : #1 — strong semantic fit to the retrieval/ranking JD; also 6y applied-AI experience (6y total). Notably demonstrated production ML deployment. no major concerns; verify depth in interview.
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ #  2  CAND_0018499  (final=0.9019)
# │  Title     : Senior Machine Learning Engineer
# │  Location  : Noida, Uttar Pradesh | Relocate: True
# │  Experience: 7y total / 7.2y applied-AI
# │  Company   : Zomato  |  Industry: Food Delivery
# │  Open2Work : True  |  Notice: 15d  |  GitHub: 94.8
# │  Sub-scores: JD=0.968  Exp=0.850  Prod=1.000  Behav=0.876  Loc=1.000  LTH=0.600  Penalty×1.00
# │  Skills    : deep learning, weaviate, recommendation systems, scikit-learn, diffusion models, pinecone, information retrieval, milvus, qlora, rag
# │  Reasoning : Selected (#2) for strong semantic fit to the retrieval/ranking JD plus 7y applied-AI experience (7y total). Demonstrated production ml deployment. no major concerns; verify depth in interview.
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ #  3  CAND_0086022  (final=0.8558)
# │  Title     : Senior Applied Scientist
# │  Location  : Kolkata, West Bengal | Relocate: True
# │  Experience: 5y total / 5.2y applied-AI
# │  Company   : Sarvam Ai  |  Industry: Ai/Ml
# │  Open2Work : True  |  Notice: 0d  |  GitHub: 75.2
# │  Sub-scores: JD=0.859  Exp=0.940  Prod=1.000  Behav=0.801  Loc=0.800  LTH=0.600  Penalty×1.00
# │  Skills    : vector search, mlflow, recommendation systems, databricks, deep learning, pgvector, fine-tuning llms, elasticsearch, qlora, pinecone
# │  Reasoning : #3: combines strong semantic fit to the retrieval/ranking JD with 5y applied-AI experience (5y total) and demonstrated production ML deployment. no major concerns; verify depth in interview.
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ #  4  CAND_0081846  (final=0.8312)
# │  Title     : Lead Ai Engineer
# │  Location  : Jaipur, Rajasthan | Relocate: True
# │  Experience: 7y total / 6.6y applied-AI
# │  Company   : Razorpay  |  Industry: Fintech
# │  Open2Work : True  |  Notice: 30d  |  GitHub: 33.7
# │  Sub-scores: JD=0.971  Exp=0.940  Prod=1.000  Behav=0.895  Loc=0.800  LTH=0.800  Penalty×1.00
# │  Skills    : data science, information retrieval, llamaindex, pgvector, forecasting, learning to rank, elasticsearch, pytorch, vector search, scikit-learn
# │  Reasoning : Ranked #4: strong semantic fit to the retrieval/ranking JD and 7y applied-AI experience (7y total), with demonstrated production ML deployment. minor flag: 10 expert skills (implausible breadth).
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ #  5  CAND_0096142  (final=0.8283)
# │  Title     : Applied Ml Engineer
# │  Location  : Hyderabad, Telangana | Relocate: False
# │  Experience: 5y total / 5.0y applied-AI
# │  Company   : Upgrad  |  Industry: Edtech
# │  Open2Work : True  |  Notice: 120d  |  GitHub: 80.5
# │  Sub-scores: JD=0.745  Exp=1.000  Prod=1.000  Behav=0.799  Loc=0.950  LTH=0.400  Penalty×1.00
# │  Skills    : kubeflow, lora, weaviate, pinecone, python, css, bentoml, weights & biases, rag, cnn
# │  Reasoning : #5 — strong semantic fit to the retrieval/ranking JD; also 5y applied-AI experience (5y total). Notably demonstrated production ML deployment. longer notice period (~120d).
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ #  6  CAND_0069905  (final=0.8273)
# │  Title     : Applied Ml Engineer
# │  Location  : Bhubaneswar, Odisha | Relocate: True
# │  Experience: 7y total / 6.5y applied-AI
# │  Company   : Sarvam Ai  |  Industry: Ai/Ml
# │  Open2Work : True  |  Notice: 90d  |  GitHub: 44.8
# │  Sub-scores: JD=0.753  Exp=0.940  Prod=1.000  Behav=0.822  Loc=0.800  LTH=0.600  Penalty×1.00
# │  Skills    : flask, redux, lora, computer vision, speech recognition, image classification, recommendation systems, sentence transformers, langchain, tensorflow
# │  Reasoning : Selected (#6) for strong semantic fit to the retrieval/ranking JD plus 6y applied-AI experience (7y total). Demonstrated production ml deployment. longer notice period (~90d).
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ #  7  CAND_0027691  (final=0.8255)
# │  Title     : Nlp Engineer
# │  Location  : Pune, Maharashtra | Relocate: False
# │  Experience: 6y total / 6.3y applied-AI
# │  Company   : Haptik  |  Industry: Conversational Ai
# │  Open2Work : True  |  Notice: 15d  |  GitHub: 58.5
# │  Sub-scores: JD=0.694  Exp=0.940  Prod=1.000  Behav=0.796  Loc=1.000  LTH=0.600  Penalty×1.00
# │  Skills    : sap, lora, peft, recommendation systems, statistical modeling, weaviate, scikit-learn, marketing, embeddings, learning to rank
# │  Reasoning : #7: combines strong semantic fit to the retrieval/ranking JD with 6y applied-AI experience (6y total) and demonstrated production ML deployment. no major concerns; verify depth in interview.
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ #  8  CAND_0061265  (final=0.8164)
# │  Title     : Recommendation Systems Engineer
# │  Location  : Delhi, Delhi | Relocate: False
# │  Experience: 7y total / 6.5y applied-AI
# │  Company   : Zoho  |  Industry: Saas
# │  Open2Work : True  |  Notice: 120d  |  GitHub: 79.8
# │  Sub-scores: JD=0.717  Exp=0.940  Prod=1.000  Behav=0.722  Loc=0.950  LTH=0.600  Penalty×1.00
# │  Skills    : qdrant, sql, accounting, langchain, learning to rank, vector search, hugging face transformers, qlora, embeddings, time series
# │  Reasoning : Ranked #8: strong semantic fit to the retrieval/ranking JD and 6y applied-AI experience (7y total), with demonstrated production ML deployment. longer notice period (~120d).
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ #  9  CAND_0005260  (final=0.8156)
# │  Title     : Senior Nlp Engineer
# │  Location  : Chennai, Tamil Nadu | Relocate: True
# │  Experience: 5y total / 5.1y applied-AI
# │  Company   : Netflix  |  Industry: Media
# │  Open2Work : False  |  Notice: 60d  |  GitHub: -1.0
# │  Sub-scores: JD=0.890  Exp=0.940  Prod=1.000  Behav=0.604  Loc=0.800  LTH=0.400  Penalty×1.00
# │  Skills    : statistical modeling, mlops, snowflake, prompt engineering, information retrieval, speech recognition, semantic search, deep learning, python, nlp
# │  Reasoning : #9 — strong semantic fit to the retrieval/ranking JD; also 5y applied-AI experience (5y total). Notably demonstrated production ML deployment. no major concerns; verify depth in interview.
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ # 10  CAND_0054394  (final=0.8152)
# │  Title     : Recommendation Systems Engineer
# │  Location  : Pune, Maharashtra | Relocate: False
# │  Experience: 4y total / 4.0y applied-AI
# │  Company   : Pharmeasy  |  Industry: Healthtech
# │  Open2Work : True  |  Notice: 30d  |  GitHub: 31.5
# │  Sub-scores: JD=0.747  Exp=0.840  Prod=1.000  Behav=0.887  Loc=1.000  LTH=0.400  Penalty×1.00
# │  Skills    : prompt engineering, mlflow, time series, fine-tuning llms, node.js, data science, embeddings, haystack, pinecone, java
# │  Reasoning : Selected (#10) for strong semantic fit to the retrieval/ranking JD plus 4y applied-AI experience (4y total). Demonstrated production ml deployment. no major concerns; verify depth in interview.
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ # 11  CAND_0040178  (final=0.8151)
# │  Title     : Ml Engineer
# │  Location  : Pune, Maharashtra | Relocate: False
# │  Experience: 5y total / 4.9y applied-AI
# │  Company   : Meesho  |  Industry: E-Commerce
# │  Open2Work : True  |  Notice: 60d  |  GitHub: 19.7
# │  Sub-scores: JD=0.637  Exp=1.000  Prod=1.000  Behav=0.760  Loc=1.000  LTH=0.600  Penalty×1.00
# │  Skills    : weaviate, fine-tuning llms, tts, vector search, learning to rank, weights & biases, yolo, mlflow, prompt engineering, css
# │  Reasoning : #11: combines 5y applied-AI experience (5y total) with strong semantic fit to the retrieval/ranking JD and demonstrated production ML deployment. no major concerns; verify depth in interview.
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ # 12  CAND_0018549  (final=0.8148)
# │  Title     : Recommendation Systems Engineer
# │  Location  : Coimbatore, Tamil Nadu | Relocate: True
# │  Experience: 7y total / 6.8y applied-AI
# │  Company   : Uber  |  Industry: Transportation
# │  Open2Work : True  |  Notice: 60d  |  GitHub: 56.3
# │  Sub-scores: JD=0.774  Exp=0.940  Prod=1.000  Behav=0.831  Loc=0.800  LTH=0.400  Penalty×1.00
# │  Skills    : computer vision, weaviate, kubernetes, elasticsearch, bigquery, langchain, qdrant, milvus, fine-tuning llms, speech recognition
# │  Reasoning : Ranked #12: strong semantic fit to the retrieval/ranking JD and 7y applied-AI experience (7y total), with demonstrated production ML deployment. no major concerns; verify depth in interview.
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ # 13  CAND_0091909  (final=0.8105)
# │  Title     : Machine Learning Engineer
# │  Location  : Bangalore, Karnataka | Relocate: True
# │  Experience: 7y total / 6.8y applied-AI
# │  Company   : Rephrase.Ai  |  Industry: Ai/Ml
# │  Open2Work : True  |  Notice: 45d  |  GitHub: 49.7
# │  Sub-scores: JD=0.731  Exp=0.940  Prod=1.000  Behav=0.754  Loc=0.800  LTH=0.600  Penalty×1.00
# │  Skills    : llms, image classification, pinecone, diffusion models, qlora, qdrant, opensearch, bentoml, scikit-learn, sentence transformers
# │  Reasoning : #13 — strong semantic fit to the retrieval/ranking JD; also 7y applied-AI experience (7y total). Notably demonstrated production ML deployment. no major concerns; verify depth in interview.
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ # 14  CAND_0041669  (final=0.8104)
# │  Title     : Recommendation Systems Engineer
# │  Location  : Noida, Uttar Pradesh | Relocate: False
# │  Experience: 8y total / 7.9y applied-AI
# │  Company   : Cred  |  Industry: Fintech
# │  Open2Work : True  |  Notice: 60d  |  GitHub: 70.9
# │  Sub-scores: JD=0.751  Exp=0.850  Prod=1.000  Behav=0.834  Loc=1.000  LTH=0.400  Penalty×1.00
# │  Skills    : faiss, milvus, peft, diffusion models, mlflow, qlora, haystack, semantic search, weaviate, prompt engineering
# │  Reasoning : Selected (#14) for strong semantic fit to the retrieval/ranking JD plus 8y applied-AI experience (8y total). Demonstrated production ml deployment. no major concerns; verify depth in interview.
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ # 15  CAND_0068811  (final=0.8096)
# │  Title     : Applied Ml Engineer
# │  Location  : Pune, Maharashtra | Relocate: True
# │  Experience: 8y total / 7.9y applied-AI
# │  Company   : Freshworks  |  Industry: Saas
# │  Open2Work : True  |  Notice: 30d  |  GitHub: 23.1
# │  Sub-scores: JD=0.738  Exp=0.850  Prod=1.000  Behav=0.855  Loc=1.000  LTH=0.400  Penalty×1.00
# │  Skills    : data science, vector search, speech recognition, tts, kubeflow, qdrant, scikit-learn, tensorflow, embeddings, pgvector
# │  Reasoning : #15: combines strong semantic fit to the retrieval/ranking JD with 8y applied-AI experience (8y total) and demonstrated production ML deployment. no major concerns; verify depth in interview.
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ # 16  CAND_0041610  (final=0.8089)
# │  Title     : Recommendation Systems Engineer
# │  Location  : Indore, Madhya Pradesh | Relocate: True
# │  Experience: 7y total / 6.6y applied-AI
# │  Company   : Zoho  |  Industry: Saas
# │  Open2Work : True  |  Notice: 30d  |  GitHub: 52.1
# │  Sub-scores: JD=0.672  Exp=0.940  Prod=1.000  Behav=0.862  Loc=0.800  LTH=0.600  Penalty×1.00
# │  Skills    : opencv, lora, statistical modeling, data science, elasticsearch, gans, opensearch, langchain, bm25, scikit-learn
# │  Reasoning : Ranked #16: strong semantic fit to the retrieval/ranking JD and 7y applied-AI experience (7y total), with demonstrated production ML deployment. no major concerns; verify depth in interview.
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ # 17  CAND_0094759  (final=0.8078)
# │  Title     : Lead Ai Engineer
# │  Location  : Mumbai, Maharashtra | Relocate: True
# │  Experience: 9y total / 8.4y applied-AI
# │  Company   : Meta  |  Industry: Internet
# │  Open2Work : False  |  Notice: 30d  |  GitHub: 76.2
# │  Sub-scores: JD=0.859  Exp=0.850  Prod=1.000  Behav=0.367  Loc=0.950  LTH=0.800  Penalty×1.00
# │  Skills    : prompt engineering, scikit-learn, hugging face transformers, learning to rank, semantic search, qdrant, fine-tuning llms, agile, vector search, tts
# │  Reasoning : #17 — strong semantic fit to the retrieval/ranking JD; also 8y applied-AI experience (9y total). Notably demonstrated production ML deployment. limited availability signals.
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ # 18  CAND_0052328  (final=0.8053)
# │  Title     : Recommendation Systems Engineer
# │  Location  : Pune, Maharashtra | Relocate: False
# │  Experience: 6y total / 6.4y applied-AI
# │  Company   : Amazon  |  Industry: Internet
# │  Open2Work : True  |  Notice: 30d  |  GitHub: 77.6
# │  Sub-scores: JD=0.597  Exp=0.940  Prod=1.000  Behav=0.854  Loc=1.000  LTH=0.600  Penalty×1.00
# │  Skills    : object detection, lora, opensearch, reinforcement learning, qlora, image classification, recommendation systems, asr, computer vision, learning to rank
# │  Reasoning : Selected (#18) for 6y applied-AI experience (6y total) plus strong semantic fit to the retrieval/ranking JD. Demonstrated production ml deployment. no major concerns; verify depth in interview.
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ # 19  CAND_0070525  (final=0.8008)
# │  Title     : Senior Software Engineer (Ml)
# │  Location  : Hyderabad, Telangana | Relocate: False
# │  Experience: 5y total / 5.3y applied-AI
# │  Company   : Mad Street Den  |  Industry: Ai/Ml
# │  Open2Work : True  |  Notice: 45d  |  GitHub: 18.4
# │  Sub-scores: JD=0.619  Exp=0.940  Prod=1.000  Behav=0.947  Loc=0.950  LTH=0.400  Penalty×1.00
# │  Skills    : apache beam, recommendation systems, feature engineering, python, gans, statistical modeling, azure, yolo, prompt engineering, llms
# │  Reasoning : #19: combines 5y applied-AI experience (5y total) with strong semantic fit to the retrieval/ranking JD and demonstrated production ML deployment. no major concerns; verify depth in interview.
# └──────────────────────────────────────────────────────────────────────────────
#
# ┌─ # 20  CAND_0005649  (final=0.8004)
# │  Title     : Senior Data Scientist
# │  Location  : Delhi, Delhi | Relocate: True
# │  Experience: 7y total / 7.3y applied-AI
# │  Company   : Sarvam Ai  |  Industry: Ai/Ml
# │  Open2Work : True  |  Notice: 90d  |  GitHub: 80.7
# │  Sub-scores: JD=0.768  Exp=0.850  Prod=1.000  Behav=0.767  Loc=0.950  LTH=0.400  Penalty×1.00
# │  Skills    : haystack, redis, prompt engineering, object detection, deep learning, tensorflow, fine-tuning llms, recommendation systems, qlora, opencv
# │  Reasoning : Ranked #20: strong semantic fit to the retrieval/ranking JD and 7y applied-AI experience (7y total), with demonstrated production ML deployment. longer notice period (~90d).
# └──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## Notes, Assumptions & Tuning Knobs
#
# **Key design decisions:**
# - **Location filter** — Per JD lines 5 & 79: Pune/Noida preferred, Delhi NCR/Mumbai/Hyderabad welcome. "Open to relocation candidates from Tier-1 Indian cities." Elimination only fires if NOT in named hubs AND NOT willing to relocate. Indian candidates willing to relocate pass but score 0.80 (vs 1.0 for Pune/Noida, 0.95 for secondary hubs).
# - **Consulting list** — Broadened to ~50 real company names (Indian IT services + global outsourcing). Fictional/unknown companies do NOT match and are never penalized.
# - **Dense embeddings (late-stage)** — Phase 1 scores ALL survivors with BM25 + TF-IDF (fast). Phase 2 only encodes the top `DENSE_SHORTLIST_N=500` candidates with sentence-transformers. This keeps the expensive step to ~500 encodings rather than 20-50K.
# - **Recency anchor** — the dataset is dated in the future, so `days_since_active` is measured from the *max* `last_active_date`. Set `REFERENCE_DATE` to fix this.
# - **Applied-AI years** — estimated by summing tenure of roles whose title/description show AI/ML evidence (heuristic, not a labeled field).
# - **Weights** in `WEIGHTS` are a sensible starting point; the spec calls for pairwise recruiter-style tuning.
#
# **Tuning knobs:**
# - `WEIGHTS` — adjust relative importance of sub-scores.
# - `DENSE_SHORTLIST_N` — increase for better dense-embedding coverage (slower), decrease for speed.
# - `HONEYPOT_REJECT_THRESHOLD` — lower = more aggressive honeypot rejection.
# - `USE_DENSE_EMBEDDINGS = False` — skip dense entirely if model unavailable or for speed.
